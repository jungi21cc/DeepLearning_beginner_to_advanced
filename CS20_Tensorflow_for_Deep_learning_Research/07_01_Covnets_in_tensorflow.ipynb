# %% [markdown]
# # lecture 7
# # convolution neural networks in tensorflow

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import tensorflow as tf
import tensorflow.contrib.layers as layers
from tensorflow.examples.tutorials.mnist import input_data

from examples import utils
import time 
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

# %%
# tf.nn.conv2d(
#     input,
#     filter,
#     strides,
#     padding,
#     use_cudnn_on_gpu=True,
#     data_format='NHWC',
#     dilations=[1, 1, 1, 1],
#     name=None
# )

# %%
# Step 1: Read in data
# using TF Learn's built in function to load MNIST data to the folder data/mnist
mnist = input_data.read_data_sets("examples/data/mnist", one_hot=True)
# Out:
# WARNING:tensorflow:From <ipython-input-3-d7665a19b72a>:3: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/jk/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/jk/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting examples/data/mnist/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /home/jk/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting examples/data/mnist/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/jk/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting examples/data/mnist/t10k-images-idx3-ubyte.gz
# Extracting examples/data/mnist/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/jk/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
# Step 2: Define paramaters for the model
LEARNING_RATE = 0.001
BATCH_SIZE = 128
SKIP_STEP = 100
DROPOUT = 0.75
N_EPOCHS = 4
N_CLASSES = 10

# %%
# Step 3: create placeholders for features and labels
# each image in the MNIST data is of shape 28*28 = 784
# therefore, each image is represented with a 1x784 tensor
# We'll be doing dropout for hidden layer so we'll need a placeholder
# for the dropout probability too
# Use None for shape so we can change the batch_size once we've built the graph
with tf.name_scope('data'):
    X = tf.placeholder(tf.float32, [None, 784], name="X_placeholder")
    Y = tf.placeholder(tf.float32, [None, 10], name="Y_placeholder")

dropout = tf.placeholder(tf.float32, name='dropout')

# %%
# Step 4 + 5: create weights + do inference
# the model is conv -> relu -> pool -> conv -> relu -> pool -> fully connected -> softmax

global_step = tf.Variable(0, dtype=tf.int32, trainable=False, name='global_step')

with tf.variable_scope('conv1') as scope:
    # first, reshape the image to [BATCH_SIZE, 28, 28, 1] to make it work with tf.nn.conv2d
    images = tf.reshape(X, shape=[-1, 28, 28, 1]) 
    kernel = tf.get_variable('kernel', [5, 5, 1, 32], 
                            initializer=tf.truncated_normal_initializer())
    biases = tf.get_variable('biases', [32],
                        initializer=tf.random_normal_initializer())
    conv = tf.nn.conv2d(images, kernel, strides=[1, 1, 1, 1], padding='SAME')
    conv1 = tf.nn.relu(conv + biases, name=scope.name)

    # output is of dimension BATCH_SIZE x 28 x 28 x 32
    conv1 = layers.conv2d(images, 32, 5, 1, activation_fn=tf.nn.relu, padding='SAME')

with tf.variable_scope('pool1') as scope:
    pool1 = tf.nn.max_pool(conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1],
                           padding='SAME')

    # output is of dimension BATCH_SIZE x 14 x 14 x 32

with tf.variable_scope('conv2') as scope:
    # similar to conv1, except kernel now is of the size 5 x 5 x 32 x 64
    kernel = tf.get_variable('kernels', [5, 5, 32, 64], 
                        initializer=tf.truncated_normal_initializer())
    biases = tf.get_variable('biases', [64],
                        initializer=tf.random_normal_initializer())
    conv = tf.nn.conv2d(pool1, kernel, strides=[1, 1, 1, 1], padding='SAME')
    conv2 = tf.nn.relu(conv + biases, name=scope.name)

    # output is of dimension BATCH_SIZE x 14 x 14 x 64
    # layers.conv2d(images, 64, 5, 1, activation_fn=tf.nn.relu, padding='SAME')

with tf.variable_scope('pool2') as scope:
    # similar to pool1
    pool2 = tf.nn.max_pool(conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1],
                            padding='SAME')

    # output is of dimension BATCH_SIZE x 7 x 7 x 64

with tf.variable_scope('fc') as scope:
    # use weight of dimension 7 * 7 * 64 x 1024
    input_features = 7 * 7 * 64
    w = tf.get_variable('weights', [input_features, 1024],
                        initializer=tf.truncated_normal_initializer())
    b = tf.get_variable('biases', [1024],
                        initializer=tf.constant_initializer(0.0))

    # reshape pool2 to 2 dimensional
    pool2 = tf.reshape(pool2, [-1, input_features])
    fc = tf.nn.relu(tf.matmul(pool2, w) + b, name='relu')
    
    # pool2 = layers.flatten(pool2)
    # fc = layers.fully_connected(pool2, 1024, tf.nn.relu)

    fc = tf.nn.dropout(fc, dropout, name='relu_dropout')

with tf.variable_scope('softmax_linear') as scope:
    w = tf.get_variable('weights', [1024, N_CLASSES],
                        initializer=tf.truncated_normal_initializer())
    b = tf.get_variable('biases', [N_CLASSES],
                        initializer=tf.random_normal_initializer())
    logits = tf.matmul(fc, w) + b

# %%
# Step 6: define loss function
# use softmax cross entropy with logits as the loss function
# compute mean cross entropy, softmax is applied internally
with tf.name_scope('loss'):
    entropy = tf.nn.softmax_cross_entropy_with_logits(labels=Y, logits=logits)
    loss = tf.reduce_mean(entropy, name='loss')

with tf.name_scope('summaries'):
    tf.summary.scalar('loss', loss)
    tf.summary.histogram('histogram loss', loss)
    summary_op = tf.summary.merge_all()
# Out:
# WARNING:tensorflow:From <ipython-input-7-920093d94cc0>:5: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# INFO:tensorflow:Summary name histogram loss is illegal; using histogram_loss instead.

# %%
# Step 7: define training op
# using gradient descent with learning rate of LEARNING_RATE to minimize cost
optimizer = tf.train.AdamOptimizer(LEARNING_RATE).minimize(loss, global_step=global_step)

utils.safe_mkdir('checkpoints')
utils.safe_mkdir('checkpoints/convnet_mnist')

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    saver = tf.train.Saver()
    # to visualize using TensorBoard
    writer = tf.summary.FileWriter('./graphs/convnet', sess.graph)
    ckpt = tf.train.get_checkpoint_state(os.path.dirname('checkpoints/convnet_mnist/checkpoint'))
    # if that checkpoint exists, restore from checkpoint
    if ckpt and ckpt.model_checkpoint_path:
        saver.restore(sess, ckpt.model_checkpoint_path)
    
    initial_step = global_step.eval()

    start_time = time.time()
    n_batches = int(mnist.train.num_examples / BATCH_SIZE)

    total_loss = 0.0
    for index in range(initial_step, n_batches * N_EPOCHS): # train the model n_epochs times
        X_batch, Y_batch = mnist.train.next_batch(BATCH_SIZE)
        _, loss_batch, summary = sess.run([optimizer, loss, summary_op], 
                                feed_dict={X: X_batch, Y:Y_batch, dropout: DROPOUT}) 
        writer.add_summary(summary, global_step=index)
        total_loss += loss_batch
        if (index + 1) % SKIP_STEP == 0:
            print('Average loss at step {}: {:5.1f}'.format(index + 1, total_loss / SKIP_STEP))
            total_loss = 0.0
            saver.save(sess, 'checkpoints/convnet_mnist/mnist-convnet', index)
    
    print("Optimization Finished!") # should be around 0.35 after 25 epochs
    print("Total time: {0} seconds".format(time.time() - start_time))
    
    # test the model
    n_batches = int(mnist.test.num_examples/BATCH_SIZE)
    total_correct_preds = 0
    for i in range(n_batches):
        X_batch, Y_batch = mnist.test.next_batch(BATCH_SIZE)
        _, loss_batch, logits_batch = sess.run([optimizer, loss, logits], 
                                        feed_dict={X: X_batch, Y:Y_batch, dropout: 1.0}) 
        preds = tf.nn.softmax(logits_batch)
        correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(Y_batch, 1))
        accuracy = tf.reduce_sum(tf.cast(correct_preds, tf.float32))
        total_correct_preds += sess.run(accuracy)   
    
    print("Accuracy {0}".format(total_correct_preds/mnist.test.num_examples))
# Out:
# Average loss at step 10: 1730.5
# Average loss at step 20: 773.0
# Average loss at step 30: 495.2
# Average loss at step 40: 343.1
# Average loss at step 50: 229.8
# Average loss at step 60: 183.0
# Average loss at step 70: 161.3
# Average loss at step 80: 154.7
# Average loss at step 90: 116.4
# Average loss at step 100: 112.3
# Average loss at step 110: 109.1
# Average loss at step 120:  95.5
# Average loss at step 130:  82.2
# Average loss at step 140:  81.7
# Average loss at step 150:  74.4
# Average loss at step 160:  78.1
# Average loss at step 170:  54.0
# Average loss at step 180:  62.7
# Average loss at step 190:  53.0
# Average loss at step 200:  43.2
# Average loss at step 210:  50.2
# Average loss at step 220:  56.1
# Average loss at step 230:  51.1
# Average loss at step 240:  50.6
# Average loss at step 250:  46.7
# Average loss at step 260:  34.8
# Average loss at step 270:  35.6
# Average loss at step 280:  33.0
# Average loss at step 290:  33.2
# Average loss at step 300:  31.0
# Average loss at step 310:  27.5
# Average loss at step 320:  28.8
# Average loss at step 330:  35.8
# Average loss at step 340:  28.8
# Average loss at step 350:  25.1
# Average loss at step 360:  22.9
# Average loss at step 370:  26.5
# Average loss at step 380:  18.0
# Average loss at step 390:  20.0
# Average loss at step 400:  23.1
# Average loss at step 410:  17.1
# Average loss at step 420:  22.9
# Average loss at step 430:  21.5
# Average loss at step 440:  19.6
# Average loss at step 450:  23.1
# Average loss at step 460:  21.0
# Average loss at step 470:  16.5
# Average loss at step 480:  14.7
# Average loss at step 490:  15.3
# Average loss at step 500:  18.1
# Average loss at step 510:  17.8
# Average loss at step 520:  14.3
# Average loss at step 530:  15.0
# Average loss at step 540:  16.4
# Average loss at step 550:  16.4
# Average loss at step 560:  14.2
# Average loss at step 570:  14.7
# Average loss at step 580:  19.4
# Average loss at step 590:  16.7
# Average loss at step 600:  16.1
# Average loss at step 610:  13.7
# Average loss at step 620:  13.7
# Average loss at step 630:  13.7
# Average loss at step 640:  12.3
# Average loss at step 650:  11.0
# Average loss at step 660:  13.6
# Average loss at step 670:  11.1
# Average loss at step 680:  10.5
# Average loss at step 690:  13.2
# Average loss at step 700:  12.0
# Average loss at step 710:  11.6
# Average loss at step 720:  10.4
# Average loss at step 730:  10.2
# Average loss at step 740:   8.4
# Average loss at step 750:  11.0
# Average loss at step 760:   9.0
# Average loss at step 770:  12.7
# Average loss at step 780:  11.7
# Average loss at step 790:   9.9
# Average loss at step 800:  13.6
# Average loss at step 810:   7.8
# Average loss at step 820:  11.5
# Average loss at step 830:   8.0
# Average loss at step 840:   8.2
# Average loss at step 850:   9.3
# Average loss at step 860:   6.6
# Average loss at step 870:   8.3
# Average loss at step 880:   8.2
# Average loss at step 890:   7.4
# Average loss at step 900:   7.6
# Average loss at step 910:   7.4
# Average loss at step 920:   6.6
# Average loss at step 930:   9.0
# Average loss at step 940:   6.7
# Average loss at step 950:   9.1
# Average loss at step 960:   6.7
# Average loss at step 970:   9.6
# Average loss at step 980:  11.6
# Average loss at step 990:   7.3
# Average loss at step 1000:   6.3
# Average loss at step 1010:   7.9
# Average loss at step 1020:   9.0
# Average loss at step 1030:   5.1
# Average loss at step 1040:   7.7
# Average loss at step 1050:   6.6
# Average loss at step 1060:   6.2
# Average loss at step 1070:   7.7
# Average loss at step 1080:   7.3
# Average loss at step 1090:   5.9
# Average loss at step 1100:   6.4
# Average loss at step 1110:   5.5
# Average loss at step 1120:   5.4
# Average loss at step 1130:   5.8
# Average loss at step 1140:   5.3
# Average loss at step 1150:   5.7
# Average loss at step 1160:   4.0
# Average loss at step 1170:   7.8
# Average loss at step 1180:   5.1
# Average loss at step 1190:   4.7
# Average loss at step 1200:   5.1
# Average loss at step 1210:   5.0
# Average loss at step 1220:   4.7
# Average loss at step 1230:   4.5
# Average loss at step 1240:   6.0
# Average loss at step 1250:   4.3
# Average loss at step 1260:   5.7
# Average loss at step 1270:   5.8
# Average loss at step 1280:   4.8
# Average loss at step 1290:   4.4
# Average loss at step 1300:   4.6
# Average loss at step 1310:   3.6
# Average loss at step 1320:   4.6
# Average loss at step 1330:   4.7
# Average loss at step 1340:   4.7
# Average loss at step 1350:   5.7
# Average loss at step 1360:   4.7
# Average loss at step 1370:   4.3
# Average loss at step 1380:   3.7
# Average loss at step 1390:   3.6
# Average loss at step 1400:   4.4
# Average loss at step 1410:   5.3
# Average loss at step 1420:   4.0
# Average loss at step 1430:   5.1
# Average loss at step 1440:   5.0
# Average loss at step 1450:   4.7
# Average loss at step 1460:   3.5
# Average loss at step 1470:   5.4
# Average loss at step 1480:   4.0
# Average loss at step 1490:   3.8
# Average loss at step 1500:   3.9
# Average loss at step 1510:   3.8
# Average loss at step 1520:   4.0
# Average loss at step 1530:   3.4
# Average loss at step 1540:   4.9
# Average loss at step 1550:   3.9
# Average loss at step 1560:   3.6
# Average loss at step 1570:   2.5
# Average loss at step 1580:   2.6
# Average loss at step 1590:   3.9
# Average loss at step 1600:   3.5
# Average loss at step 1610:   2.5
# Average loss at step 1620:   3.8
# Average loss at step 1630:   3.9
# Average loss at step 1640:   2.8
# Average loss at step 1650:   3.6
# Average loss at step 1660:   3.9
# Average loss at step 1670:   4.0
# Average loss at step 1680:   3.2
# Average loss at step 1690:   2.6
# Average loss at step 1700:   2.6
# Average loss at step 1710:   3.4
# Average loss at step 1720:   2.5
# Average loss at step 1730:   3.4
# Average loss at step 1740:   2.9
# Average loss at step 1750:   2.7
# Average loss at step 1760:   3.1
# Average loss at step 1770:   2.7
# Average loss at step 1780:   3.3
# Average loss at step 1790:   3.4
# Average loss at step 1800:   3.5
# Average loss at step 1810:   2.6
# Average loss at step 1820:   2.3
# Average loss at step 1830:   2.3
# Average loss at step 1840:   3.0
# Average loss at step 1850:   3.3
# Average loss at step 1860:   2.4
# Average loss at step 1870:   2.4
# Average loss at step 1880:   2.9
# Average loss at step 1890:   2.9
# Average loss at step 1900:   2.1
# Average loss at step 1910:   2.9
# Average loss at step 1920:   2.7
# Average loss at step 1930:   2.5
# Average loss at step 1940:   2.1
# Average loss at step 1950:   3.6
# Average loss at step 1960:   3.1
# Average loss at step 1970:   2.1
# Average loss at step 1980:   2.9
# Average loss at step 1990:   1.6
# Average loss at step 2000:   2.3
# Average loss at step 2010:   2.1
# Average loss at step 2020:   2.3
# Average loss at step 2030:   2.4
# Average loss at step 2040:   3.0
# Average loss at step 2050:   2.3
# Average loss at step 2060:   2.5
# Average loss at step 2070:   2.3
# Average loss at step 2080:   3.3
# Average loss at step 2090:   2.6
# Average loss at step 2100:   2.6
# Average loss at step 2110:   2.3
# Average loss at step 2120:   2.3
# Average loss at step 2130:   2.4
# Average loss at step 2140:   2.2
# Average loss at step 2150:   2.1
# Average loss at step 2160:   1.7
# Average loss at step 2170:   2.7
# Average loss at step 2180:   2.2
# Average loss at step 2190:   1.7
# Average loss at step 2200:   2.1
# Average loss at step 2210:   2.2
# Average loss at step 2220:   2.0
# Average loss at step 2230:   2.2
# Average loss at step 2240:   1.6
# Average loss at step 2250:   2.5
# Average loss at step 2260:   1.8
# Average loss at step 2270:   1.8
# Average loss at step 2280:   1.8
# Average loss at step 2290:   2.2
# Average loss at step 2300:   1.7
# Average loss at step 2310:   2.2
# Average loss at step 2320:   2.3
# Average loss at step 2330:   2.8
# Average loss at step 2340:   1.8
# Average loss at step 2350:   2.3
# Average loss at step 2360:   2.2
# Average loss at step 2370:   2.4
# Average loss at step 2380:   1.8
# Average loss at step 2390:   2.1
# Average loss at step 2400:   2.2
# Average loss at step 2410:   1.6
# Average loss at step 2420:   1.3
# Average loss at step 2430:   1.8
# Average loss at step 2440:   1.8
# Average loss at step 2450:   2.0
# Average loss at step 2460:   2.0
# Average loss at step 2470:   2.4
# Average loss at step 2480:   1.6
# Average loss at step 2490:   1.7
# Average loss at step 2500:   1.3
# Average loss at step 2510:   1.3
# Average loss at step 2520:   1.8
# Average loss at step 2530:   2.1
# Average loss at step 2540:   1.9
# Average loss at step 2550:   1.8
# Average loss at step 2560:   1.6
# Average loss at step 2570:   1.7
# Average loss at step 2580:   1.4
# Average loss at step 2590:   1.4
# Average loss at step 2600:   1.7
# Average loss at step 2610:   2.1
# Average loss at step 2620:   1.3
# Average loss at step 2630:   1.4
# Average loss at step 2640:   1.7
# Average loss at step 2650:   1.9
# Average loss at step 2660:   1.7
# Average loss at step 2670:   2.0
# Average loss at step 2680:   1.5
# Average loss at step 2690:   1.2
# Average loss at step 2700:   1.9
# Average loss at step 2710:   2.0
# Average loss at step 2720:   1.6
# Average loss at step 2730:   2.5
# Average loss at step 2740:   1.5
# Average loss at step 2750:   2.4
# Average loss at step 2760:   1.7
# Average loss at step 2770:   1.6
# Average loss at step 2780:   1.9
# Average loss at step 2790:   0.9
# Average loss at step 2800:   1.5
# Average loss at step 2810:   1.6
# Average loss at step 2820:   1.5
# Average loss at step 2830:   1.3
# Average loss at step 2840:   1.8
# Average loss at step 2850:   1.5
# Average loss at step 2860:   1.6
# Average loss at step 2870:   2.1
# Average loss at step 2880:   1.8
# Average loss at step 2890:   1.4
# Average loss at step 2900:   1.3
# Average loss at step 2910:   1.2
# Average loss at step 2920:   1.7
# Average loss at step 2930:   1.4
# Average loss at step 2940:   1.7
# Average loss at step 2950:   1.7
# Average loss at step 2960:   1.9
# Average loss at step 2970:   1.6
# Average loss at step 2980:   1.6
# Average loss at step 2990:   1.3
# Average loss at step 3000:   1.5
# Average loss at step 3010:   1.0
# Average loss at step 3020:   1.0
# Average loss at step 3030:   1.1
# Average loss at step 3040:   1.4
# Average loss at step 3050:   1.1
# Average loss at step 3060:   1.2
# Average loss at step 3070:   1.0
# Average loss at step 3080:   1.4
# Average loss at step 3090:   1.3
# Average loss at step 3100:   1.3
# Average loss at step 3110:   1.1
# Average loss at step 3120:   1.2
# Average loss at step 3130:   1.1
# Average loss at step 3140:   1.0
# Average loss at step 3150:   1.2
# Average loss at step 3160:   1.4
# Average loss at step 3170:   1.3
# Average loss at step 3180:   1.5
# Average loss at step 3190:   1.6
# Average loss at step 3200:   1.3
# Average loss at step 3210:   1.4
# Average loss at step 3220:   1.3
# Average loss at step 3230:   1.1
# Average loss at step 3240:   1.3
# Average loss at step 3250:   1.1
# Average loss at step 3260:   1.5
# Average loss at step 3270:   1.6
# Average loss at step 3280:   1.5
# Average loss at step 3290:   1.5
# Average loss at step 3300:   1.7
# Average loss at step 3310:   1.3
# Average loss at step 3320:   1.4
# Average loss at step 3330:   1.5
# Average loss at step 3340:   1.4
# Average loss at step 3350:   1.6
# Average loss at step 3360:   1.6
# Average loss at step 3370:   1.1
# Average loss at step 3380:   1.2
# Average loss at step 3390:   1.3
# Average loss at step 3400:   1.2
# Average loss at step 3410:   1.2
# Average loss at step 3420:   1.3
# Average loss at step 3430:   1.0
# Average loss at step 3440:   1.0
# Average loss at step 3450:   1.3
# Average loss at step 3460:   1.0
# Average loss at step 3470:   1.4
# Average loss at step 3480:   1.5
# Average loss at step 3490:   1.2
# Average loss at step 3500:   1.5
# Average loss at step 3510:   1.3
# Average loss at step 3520:   1.2
# Average loss at step 3530:   1.2
# Average loss at step 3540:   1.1
# Average loss at step 3550:   0.9
# Average loss at step 3560:   1.1
# Average loss at step 3570:   1.1
# Average loss at step 3580:   1.0
# Average loss at step 3590:   1.1
# Average loss at step 3600:   1.2
# Average loss at step 3610:   1.0
# Average loss at step 3620:   1.1
# Average loss at step 3630:   0.8
# Average loss at step 3640:   1.1
# Average loss at step 3650:   1.1
# Average loss at step 3660:   0.7
# Average loss at step 3670:   1.0
# Average loss at step 3680:   1.2
# Average loss at step 3690:   0.7
# Average loss at step 3700:   0.9
# Average loss at step 3710:   1.3
# Average loss at step 3720:   0.9
# Average loss at step 3730:   1.0
# Average loss at step 3740:   1.1
# Average loss at step 3750:   1.1
# Average loss at step 3760:   1.5
# Average loss at step 3770:   0.7
# Average loss at step 3780:   0.7
# Average loss at step 3790:   1.3
# Average loss at step 3800:   1.0
# Average loss at step 3810:   1.1
# Average loss at step 3820:   1.2
# Average loss at step 3830:   0.9
# Average loss at step 3840:   0.9
# Average loss at step 3850:   1.5
# Average loss at step 3860:   1.2
# Average loss at step 3870:   0.9
# Average loss at step 3880:   0.9
# Average loss at step 3890:   1.1
# Average loss at step 3900:   0.8
# Average loss at step 3910:   0.9
# Average loss at step 3920:   0.9
# Average loss at step 3930:   0.9
# Average loss at step 3940:   0.8
# Average loss at step 3950:   1.0
# Average loss at step 3960:   0.8
# Average loss at step 3970:   0.8
# Average loss at step 3980:   0.7
# Average loss at step 3990:   1.1
# Average loss at step 4000:   1.0
# Average loss at step 4010:   1.1
# Average loss at step 4020:   0.7
# Average loss at step 4030:   0.9
# Average loss at step 4040:   0.9
# Average loss at step 4050:   1.0
# Average loss at step 4060:   1.0
# Average loss at step 4070:   1.1
# Average loss at step 4080:   1.3
# Average loss at step 4090:   0.7
# Average loss at step 4100:   0.8
# Average loss at step 4110:   1.0
# Average loss at step 4120:   0.8
# Average loss at step 4130:   0.8
# Average loss at step 4140:   1.5
# Average loss at step 4150:   0.7
# Average loss at step 4160:   1.0
# Average loss at step 4170:   1.1
# Average loss at step 4180:   0.7
# Average loss at step 4190:   0.7
# Average loss at step 4200:   0.8
# Average loss at step 4210:   1.1
# Average loss at step 4220:   1.1
# Average loss at step 4230:   0.9
# Average loss at step 4240:   1.0
# Average loss at step 4250:   0.9
# Average loss at step 4260:   0.8
# Average loss at step 4270:   0.9
# Average loss at step 4280:   0.8
# Average loss at step 4290:   0.9
# Optimization Finished!
# Total time: 1667.3458452224731 seconds
# Accuracy 0.9609
