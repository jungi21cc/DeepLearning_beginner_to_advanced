# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import sys
import argparse
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

from tensorflow.contrib.tensorboard.plugins import projector

# %%
# Give a folder path as an argument with '--log_dir' to save
# TensorBoard summaries. Default is a log folder in current directory.
current_path = os.path.dirname(os.path.realpath(sys.argv[0]))

parser = argparse.ArgumentParser()
parser.add_argument(
    '--log_dir',
    type=str,
    default=os.path.join(current_path, 'log'),
    help='The log directory for TensorBoard summaries.')
FLAGS, unparsed = parser.parse_known_args()

# Create the directory for TensorBoard variables if there is not.
if not os.path.exists(FLAGS.log_dir):
  os.makedirs(FLAGS.log_dir)

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

# %%
# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    local_filename = os.path.join(gettempdir(), filename)
    if not os.path.exists(local_filename):
        local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
    statinfo = os.stat(local_filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + local_filename +
                        '. Can you get to it with a browser?')
    return local_filename


filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words."""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

# %%
# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(
    vocabulary, vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)  # pylint: disable=redefined-builtin
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            buffer.extend(data[0:span])
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
        reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 2 of
# 195 term -> 6 a

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

graph = tf.Graph()

# %%
with graph.as_default():

    # Input data.
    with tf.name_scope('inputs'):
        train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
        train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
        valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
        with tf.name_scope('embeddings'):
            embeddings = tf.Variable(
              tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
            embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        with tf.name_scope('weights'):
            nce_weights = tf.Variable(
              tf.truncated_normal(
                  [vocabulary_size, embedding_size],
                  stddev=1.0 / math.sqrt(embedding_size)))
        with tf.name_scope('biases'):
            nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    # Explanation of the meaning of NCE loss:
    #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
    with tf.name_scope('loss'):
        loss = tf.reduce_mean(
            tf.nn.nce_loss(
                weights=nce_weights,
                biases=nce_biases,
                labels=train_labels,
                inputs=embed,
                num_sampled=num_sampled,
                num_classes=vocabulary_size))

    # Add the loss value as a scalar to summary.
    tf.summary.scalar('loss', loss)

    # Construct the SGD optimizer using a learning rate of 1.0.
    with tf.name_scope('optimizer'):
        optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                            valid_dataset)
    similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

    # Merge all summaries.
    merged = tf.summary.merge_all()

    # Add variable initializer.
    init = tf.global_variables_initializer()

    # Create a saver.
    saver = tf.train.Saver()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # Open a writer to write summaries.
    writer = tf.summary.FileWriter(FLAGS.log_dir, session.graph)

    # We must initialize all variables before we use them.
    init.run()
    print('Initialized')

    average_loss = 0
    for step in xrange(num_steps):
        batch_inputs, batch_labels = generate_batch(batch_size, num_skips,
                                                    skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # Define metadata variable.
        run_metadata = tf.RunMetadata()

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        # Also, evaluate the merged op to get all summaries from the returned "summary" variable.
        # Feed metadata variable to session for visualizing the graph in TensorBoard.
        _, summary, loss_val = session.run(
            [optimizer, merged, loss],
            feed_dict=feed_dict,
            run_metadata=run_metadata)
        average_loss += loss_val

        # Add returned summaries to writer in each step.
        writer.add_summary(summary, step)
        # Add metadata to visualize the graph for the last run.
        if step == (num_steps - 1):
            writer.add_run_metadata(run_metadata, 'step%d' % step)

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step ', step, ': ', average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = 'Nearest to %s:' % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = '%s %s,' % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()

    # Write corresponding labels for the embeddings.
    with open(FLAGS.log_dir + '/metadata.tsv', 'w') as f:
        for i in xrange(vocabulary_size):
            f.write(reverse_dictionary[i] + '\n')

    # Save the model for checkpoints.
    saver.save(session, os.path.join(FLAGS.log_dir, 'model.ckpt'))

    # Create a configuration for visualizing embeddings with the labels in TensorBoard.
    config = projector.ProjectorConfig()
    embedding_conf = config.embeddings.add()
    embedding_conf.tensor_name = embeddings.name
    embedding_conf.metadata_path = os.path.join(FLAGS.log_dir, 'metadata.tsv')
    projector.visualize_embeddings(writer, config)

writer.close()
# Out:
# Initialized
# Average loss at step  0 :  273.0843505859375
# Nearest to they: anglicisation, estate, contrary, fiercely, mussels, presides, novarum, manichean,
# Nearest to at: uf, gretzky, emoticons, carmen, kirov, goshen, vous, montevideo,
# Nearest to other: gaddis, brindle, marketable, canister, seaway, chirality, antipsychotic, slovene,
# Nearest to have: overkill, kamen, scriptures, hillsborough, disclosed, wallonia, abiogenesis, snipers,
# Nearest to war: evaluates, carpenter, progs, creek, errors, calamity, remembering, dubliners,
# Nearest to was: murdering, allusions, newsletter, inspirations, farewell, lucca, trademarks, saad,
# Nearest to may: recharge, bearing, voters, kerry, thucydides, ideals, practiced, raisins,
# Nearest to who: cx, recreational, scholastics, kabaddi, bridget, veritable, fantastically, bombarding,
# Nearest to such: dravidian, altman, collective, rings, risking, extrasolar, carve, leonidas,
# Nearest to five: procter, beginner, dimensionality, patronymic, housework, kicking, dean, jaeger,
# Nearest to than: batman, gianfranco, vcjd, aid, ostracism, expire, sokal, optional,
# Nearest to called: opting, prehistoric, caterpillars, manuscripts, wove, waiting, noll, memex,
# Nearest to d: ruck, bulwer, playoffs, tammy, provably, monopolies, borrelly, enlistment,
# Nearest to three: describe, bestowing, basics, tremolo, jdk, infringed, bred, kilometers,
# Nearest to american: ter, thenceforth, elastic, garde, coffins, thames, bethlen, gogo,
# Nearest to with: iscariot, fluorescent, keeps, richards, petrified, cancel, jak, nabla,
# Average loss at step  2000 :  113.88058693122863
# Average loss at step  4000 :  52.617587381124494
# Average loss at step  6000 :  33.19818905162811
# Average loss at step  8000 :  23.6871548807621
# Average loss at step  10000 :  17.802348062515257
# Nearest to they: fins, estate, hand, opinions, contrary, would, reginae, pair,
# Nearest to at: UNK, in, of, and, gretzky, archie, utilitarian, huxley,
# Nearest to other: completed, mainly, silk, lafayette, latin, executive, receiving, alaskan,
# Nearest to have: and, hillsborough, had, has, parties, be, korchnoi, are,
# Nearest to war: errors, coke, operated, creek, microscopy, one, ports, neurology,
# Nearest to was: is, phi, had, taurus, by, principles, aries, coke,
# Nearest to may: voters, vs, bearing, practiced, ideals, educator, recharge, hints,
# Nearest to who: and, UNK, coke, archie, champion, think, barbuda, behaviour,
# Nearest to such: yeast, variation, district, coke, ipa, seen, angry, regulars,
# Nearest to five: nine, three, vs, seven, zero, two, coke, lymphoma,
# Nearest to than: nine, aid, archie, optional, unique, gland, verdict, atom,
# Nearest to called: prehistoric, waiting, nonempty, risk, rudolph, wodehouse, coke, crossbar,
# Nearest to d: changed, variants, monopolies, arising, wiesenthal, committed, gland, anthropologist,
# Nearest to three: vs, nine, five, zero, one, two, coke, six,
# Nearest to american: garde, and, thenceforth, lymphoma, vs, football, latin, thames,
# Nearest to with: in, and, of, collaborative, archie, animal, for, by,
# Average loss at step  12000 :  13.975864532470704
# Average loss at step  14000 :  11.994004552960396
# Average loss at step  16000 :  9.965896804213523
# Average loss at step  18000 :  8.435147911071777
# Average loss at step  20000 :  7.975539581418038
# Nearest to they: he, not, fins, brahma, would, abalone, it, opinions,
# Nearest to at: in, of, and, agouti, archie, utilitarian, dasyprocta, with,
# Nearest to other: completed, silk, caesar, dasyprocta, asymptotically, executive, latinus, grams,
# Nearest to have: be, had, are, has, hillsborough, were, stockton, anisotropic,
# Nearest to war: errors, agouti, operated, coke, gave, ports, joy, afonso,
# Nearest to was: is, by, had, were, are, concludes, has, agouti,
# Nearest to may: voters, would, educator, bearing, vs, hints, if, recharge,
# Nearest to who: and, coke, amazonas, UNK, heater, review, he, seven,
# Nearest to such: yeast, ipa, well, variation, adder, district, seen, coke,
# Nearest to five: nine, zero, seven, three, two, six, four, eight,
# Nearest to than: nine, aid, optional, unique, batman, coasts, wattle, verdict,
# Nearest to called: prehistoric, waiting, agouti, manuscripts, nonempty, wodehouse, operatorname, risk,
# Nearest to d: b, agouti, and, variants, mineralogy, gland, wiesenthal, births,
# Nearest to three: five, two, nine, six, four, dasyprocta, zero, eight,
# Nearest to american: and, nn, thenceforth, taoism, garde, football, vs, directors,
# Nearest to with: in, and, for, agouti, of, by, from, to,
# Average loss at step  22000 :  6.967685866951943
# Average loss at step  24000 :  6.862164148330688
# Average loss at step  26000 :  6.751002736568451
# Average loss at step  28000 :  6.373876616001129
# Average loss at step  30000 :  5.906332824349404
# Nearest to they: he, not, it, fins, would, there, who, opinions,
# Nearest to at: in, with, from, agouti, on, utilitarian, by, and,
# Nearest to other: silk, completed, latinus, executive, dasyprocta, asymptotically, caesar, grams,
# Nearest to have: had, be, has, are, were, stockton, hillsborough, abiogenesis,
# Nearest to war: calamity, errors, gave, operated, regulatory, afonso, prevented, trebizond,
# Nearest to was: is, were, by, had, has, are, phi, been,
# Nearest to may: would, can, voters, recharge, if, educator, vs, hints,
# Nearest to who: and, he, cx, amazonas, which, it, heater, they,
# Nearest to such: well, seen, yeast, variation, adder, ipa, adhd, district,
# Nearest to five: four, eight, six, zero, seven, nine, three, two,
# Nearest to than: optional, nine, eight, aid, or, and, batman, seven,
# Nearest to called: caterpillars, prehistoric, waiting, agouti, manuscripts, chassis, wodehouse, wove,
# Nearest to d: b, agouti, and, playoffs, mineralogy, variants, wiesenthal, gland,
# Nearest to three: four, five, two, six, eight, nine, seven, zero,
# Nearest to american: and, football, garde, english, nn, taoism, british, thenceforth,
# Nearest to with: in, for, by, and, agouti, at, from, between,
# Average loss at step  32000 :  5.98282091331482
# Average loss at step  34000 :  5.69450741493702
# Average loss at step  36000 :  5.784264326930046
# Average loss at step  38000 :  5.542705420374871
# Average loss at step  40000 :  5.288975530266762
# Nearest to they: he, it, not, there, who, would, fins, you,
# Nearest to at: in, on, from, utilitarian, agouti, dasyprocta, of, coke,
# Nearest to other: silk, completed, latinus, dasyprocta, executive, zero, asymptotically, slovene,
# Nearest to have: had, has, be, are, were, abiogenesis, stockton, hillsborough,
# Nearest to war: calamity, errors, regulatory, afonso, prevented, agouti, coke, trebizond,
# Nearest to was: is, were, by, has, had, been, are, phi,
# Nearest to may: would, can, recharge, might, educator, difranco, voters, could,
# Nearest to who: he, and, which, cx, they, amazonas, sabbath, blasts,
# Nearest to such: well, some, seen, variation, adhd, adder, ipa, yeast,
# Nearest to five: four, six, three, eight, seven, zero, two, nine,
# Nearest to than: or, and, ostracism, aid, optional, batman, nine, verdict,
# Nearest to called: caterpillars, prehistoric, agouti, recitative, chartered, rcs, waiting, aedh,
# Nearest to d: b, agouti, and, playoffs, mineralogy, variants, births, monopolies,
# Nearest to three: four, five, six, two, eight, seven, zero, dasyprocta,
# Nearest to american: and, english, garde, nn, british, football, shatila, taoism,
# Nearest to with: and, for, agouti, between, in, from, zero, by,
# Average loss at step  42000 :  5.368680432915688
# Average loss at step  44000 :  5.246272227287292
# Average loss at step  46000 :  5.2387445141077045
# Average loss at step  48000 :  5.2256470831632615
# Average loss at step  50000 :  4.990122971892357
# Nearest to they: he, there, not, it, you, who, we, fins,
# Nearest to at: in, on, mukherjee, utilitarian, from, agouti, dasyprocta, coke,
# Nearest to other: silk, latinus, two, completed, executive, dasyprocta, slovene, entente,
# Nearest to have: had, has, be, are, were, abiogenesis, stockton, hillsborough,
# Nearest to war: calamity, regulatory, errors, evaluates, afonso, trebizond, prevented, agouti,
# Nearest to was: is, were, had, by, has, been, are, phi,
# Nearest to may: can, would, will, could, might, must, recharge, difranco,
# Nearest to who: he, and, they, cx, which, sabbath, blasts, amazonas,
# Nearest to such: well, seen, some, these, variation, ipa, auctioned, adhd,
# Nearest to five: six, four, three, seven, eight, dasyprocta, two, agouti,
# Nearest to than: or, and, ostracism, aid, batman, verdict, nine, dissent,
# Nearest to called: caterpillars, agouti, chartered, operatorname, and, recitative, dasyprocta, rcs,
# Nearest to d: b, agouti, and, UNK, playoffs, mineralogy, five, monopolies,
# Nearest to three: four, six, five, two, seven, eight, dasyprocta, agouti,
# Nearest to american: english, british, football, nn, garde, taoism, rivals, one,
# Nearest to with: in, and, between, for, by, from, agouti, archie,
# Average loss at step  52000 :  5.05712329006195
# Average loss at step  54000 :  5.19330356836319
# Average loss at step  56000 :  5.045358687877655
# Average loss at step  58000 :  5.0600505019426345
# Average loss at step  60000 :  4.9480000902414325
# Nearest to they: he, there, it, you, who, not, we, would,
# Nearest to at: in, mukherjee, on, utilitarian, agouti, dasyprocta, during, from,
# Nearest to other: two, silk, some, different, various, three, latinus, dasyprocta,
# Nearest to have: had, has, are, were, be, abiogenesis, never, explore,
# Nearest to war: calamity, evaluates, ursus, regulatory, errors, trebizond, afonso, prevented,
# Nearest to was: is, were, had, has, by, been, be, michelob,
# Nearest to may: can, would, could, will, might, must, difranco, recharge,
# Nearest to who: he, which, they, blasts, cx, sabbath, there, she,
# Nearest to such: well, some, these, seen, variation, auctioned, many, known,
# Nearest to five: six, four, eight, three, seven, zero, nine, dasyprocta,
# Nearest to than: or, and, ostracism, seven, nine, verdict, aid, mixtures,
# Nearest to called: caterpillars, chartered, agouti, recorded, rcs, chassis, prehistoric, aedh,
# Nearest to d: b, agouti, UNK, playoffs, mineralogy, births, monopolies, five,
# Nearest to three: four, five, two, six, eight, seven, dasyprocta, michelob,
# Nearest to american: english, british, and, football, nn, taoism, lakota, two,
# Nearest to with: between, in, and, agouti, or, archie, by, michelob,
# Average loss at step  62000 :  5.024509574532509
# Average loss at step  64000 :  4.837272202968597
# Average loss at step  66000 :  4.603086316108704
# Average loss at step  68000 :  4.972573627471924
# Average loss at step  70000 :  4.892224103331566
# Nearest to they: he, there, it, you, we, not, who, these,
# Nearest to at: in, mukherjee, during, utilitarian, on, dasyprocta, three, agouti,
# Nearest to other: different, some, various, two, many, silk, capuchin, upanija,
# Nearest to have: had, has, are, were, be, dasyprocta, abiogenesis, never,
# Nearest to war: calamity, evaluates, regulatory, ursus, trebizond, afonso, errors, prevented,
# Nearest to was: is, were, had, has, by, been, michelob, are,
# Nearest to may: can, would, will, could, might, must, difranco, should,
# Nearest to who: he, they, which, blasts, and, she, cx, there,
# Nearest to such: well, these, some, seen, many, known, auctioned, other,
# Nearest to five: four, six, three, eight, seven, zero, nine, dasyprocta,
# Nearest to than: or, and, ostracism, verdict, mixtures, but, aid, dispel,
# Nearest to called: chartered, caterpillars, agouti, rcs, leontopithecus, overviews, aedh, recorded,
# Nearest to d: b, UNK, agouti, playoffs, mineralogy, seven, monopolies, gland,
# Nearest to three: four, five, six, two, seven, eight, dasyprocta, michelob,
# Nearest to american: english, british, football, and, taoism, lakota, directors, nn,
# Nearest to with: between, and, agouti, in, archie, thaler, bokassa, collaborative,
# Average loss at step  72000 :  4.744784704327583
# Average loss at step  74000 :  4.797849574685097
# Average loss at step  76000 :  4.72990459561348
# Average loss at step  78000 :  4.811624656528235
# Average loss at step  80000 :  4.8229969888329505
# Nearest to they: he, there, you, we, it, who, not, these,
# Nearest to at: in, during, on, mukherjee, from, dasyprocta, utilitarian, agouti,
# Nearest to other: different, some, various, many, capuchin, upanija, slovene, latinus,
# Nearest to have: had, has, were, are, be, explore, abiogenesis, never,
# Nearest to war: calamity, regulatory, evaluates, afonso, trebizond, ursus, prevented, errors,
# Nearest to was: is, had, were, has, by, been, became, michelob,
# Nearest to may: can, would, will, could, might, must, should, difranco,
# Nearest to who: he, they, which, blasts, there, she, trapezohedron, and,
# Nearest to such: well, these, many, seen, known, some, auctioned, upanija,
# Nearest to five: four, six, seven, eight, three, zero, nine, two,
# Nearest to than: or, and, but, ostracism, mixtures, verdict, without, aid,
# Nearest to called: iit, caterpillars, agouti, overviews, leontopithecus, chartered, rcs, operatorname,
# Nearest to d: b, agouti, UNK, mineralogy, busan, playoffs, seven, monopolies,
# Nearest to three: four, two, five, six, seven, eight, dasyprocta, agouti,
# Nearest to american: english, british, football, lakota, directors, national, taoism, strongest,
# Nearest to with: between, in, agouti, and, collaborative, michelob, thaler, archie,
# Average loss at step  82000 :  4.762112763166428
# Average loss at step  84000 :  4.760314800024033
# Average loss at step  86000 :  4.767421412706375
# Average loss at step  88000 :  4.745447528839112
# Average loss at step  90000 :  4.7271206240654
# Nearest to they: he, there, we, you, who, it, not, these,
# Nearest to at: in, during, on, mukherjee, utilitarian, dasyprocta, from, under,
# Nearest to other: some, various, different, slovene, upanija, capuchin, many, two,
# Nearest to have: had, has, were, are, be, explore, never, abiogenesis,
# Nearest to war: regulatory, calamity, evaluates, afonso, trebizond, ursus, errors, smithsonian,
# Nearest to was: is, had, were, has, by, became, been, be,
# Nearest to may: can, would, will, could, might, must, should, difranco,
# Nearest to who: he, they, and, which, blasts, she, convocation, there,
# Nearest to such: well, these, many, seen, some, known, auctioned, upanija,
# Nearest to five: seven, four, eight, six, three, zero, nine, dasyprocta,
# Nearest to than: or, but, and, ostracism, without, mixtures, verdict, dispel,
# Nearest to called: iit, agouti, chartered, leontopithecus, UNK, overviews, rcs, operatorname,
# Nearest to d: b, UNK, agouti, mineralogy, busan, playoffs, utilizing, monopolies,
# Nearest to three: four, five, two, seven, six, eight, dasyprocta, one,
# Nearest to american: english, british, lakota, directors, football, taoism, national, gobind,
# Nearest to with: between, in, agouti, from, bokassa, michelob, while, for,
# Average loss at step  92000 :  4.669955491542816
# Average loss at step  94000 :  4.708016612529755
# Average loss at step  96000 :  4.710184216737747
# Average loss at step  98000 :  4.591922817766666
# Average loss at step  100000 :  4.688543120861054
# Nearest to they: he, there, we, you, it, who, not, these,
# Nearest to at: in, during, mukherjee, on, dasyprocta, utilitarian, agouti, contention,
# Nearest to other: various, different, some, upanija, slovene, capuchin, latinus, many,
# Nearest to have: had, has, were, are, be, explore, abiogenesis, never,
# Nearest to war: calamity, regulatory, evaluates, afonso, during, ursus, trebizond, errors,
# Nearest to was: is, had, has, were, became, by, been, be,
# Nearest to may: can, would, will, could, might, must, should, difranco,
# Nearest to who: he, they, which, blasts, she, trapezohedron, convocation, and,
# Nearest to such: well, these, many, known, seen, some, auctioned, upanija,
# Nearest to five: four, seven, three, eight, six, zero, nine, two,
# Nearest to than: or, but, and, ostracism, without, much, mixtures, nine,
# Nearest to called: iit, chartered, considered, and, overviews, agouti, ovulation, caterpillars,
# Nearest to d: b, agouti, busan, six, mineralogy, utilizing, dasyprocta, UNK,
# Nearest to three: five, four, seven, two, eight, six, dasyprocta, agouti,
# Nearest to american: british, english, constituci, directors, taoism, delphinus, football, lakota,
# Nearest to with: between, in, agouti, bokassa, for, michelob, thaler, delete,

# %%
# Step 6: Visualize the embeddings.

# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
    assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(
            label,
            xy=(x, y),
            xytext=(5, 2),
            textcoords='offset points',
            ha='right',
            va='bottom')

    plt.savefig(filename)
    plt.show()

# %%
try:
  # pylint: disable=g-import-not-at-top
    from sklearn.manifold import TSNE
    import matplotlib.pyplot as plt

    tsne = TSNE(
      perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
    plot_only = 500
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

except ImportError as ex:
    print('Please install sklearn, matplotlib, and scipy to show embeddings.')
    print(ex)
